# %%
import json
import os
from langchain.llms import Ollama
from langchain.text_splitter import CharacterTextSplitter
import openai
from neo4j import GraphDatabase
from langchain_openai import ChatOpenAI

# %%
uri = os.environ["NEO4J_URI"]
user=os.environ["NEO4J_USERNAME"]
password = os.environ["NEO4J_PASSWORD"]
OPENAI_API_KEY = os.getenv["OPENAI_API_KEY"] 

driver = GraphDatabase.driver(uri, auth=(user, password))
llm = ChatOpenAI(temperature=0, model_name="gpt-4o", api_key=OPENAI_API_KEY)

# %%
# Initialize OpenAI client (new method)
client = openai.OpenAI(api_key=OPENAI_API_KEY)

def ask_openai(question, model="gpt-4o"):
    """Sends a question to OpenAI's API and returns the response."""
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": question}]
    )
    return response.choices[0].message.content

# Example Usage
question = "What is differential privacy?"
answer = ask_openai(question)
print("OpenAI Response:", answer)
# Out:
# OpenAI Response: Differential privacy is a mathematical framework designed to provide privacy guarantees when analyzing and sharing data. It aims to ensure that the removal or addition of a single individual's data in a dataset does not significantly affect the output of any analysis, thereby protecting the privacy of individuals within the dataset.
#
# The core idea is that an adversary with access to the output of a differentially private mechanism would not be able to infer much about any individual, regardless of any additional information the adversary might have. This is achieved by introducing a controlled amount of randomness (noise) into the data or the computation process, which obscures the presence or absence of individual data points.
#
# Key components of differential privacy include:
#
# 1. **ε (epsilon)**: A parameter that quantifies the privacy loss. A smaller ε indicates stronger privacy, as the outputs of computations are more indistinguishable with respect to changes in individual data.
#
# 2. **Noise Addition**: Differential privacy often involves adding noise to the data or query results. The amount and type of noise depend on the desired level of privacy (controlled by ε) and the sensitivity of the query (how much the query output can change by modifying a single individual's data).
#
# 3. **Sensitivity**: The sensitivity of a function refers to the maximum amount that a function's output can change when a single individual's data is added or removed.
#
# Differential privacy can be applied to various data analyses, including statistical queries, machine learning models, and data releases. It is widely used in scenarios where data privacy is critical, such as in census data collection, medical studies, and commercial data analytics.

# %%
ollama = Ollama(base_url='http://localhost:11434', model="llama3.1:70b")
# Out:
# /tmp/ipykernel_2235127/2524497889.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   ollama = Ollama(base_url='http://localhost:11434', model="llama3.1:70b")

# %%
# system_prompt = """
# # Knowledge Graph Instructions for llama
# ## 1. Overview
# You are a top-tier algorithm designed for extracting information in structured formats to build a knowledge graph.
# - **Nodes** represent entities and concepts.
# - **Relationships** represent the links between nodes.
# - Ensure numerical values (e.g., episode count, dates, measurements, or other quantifiable details) are captured and assigned appropriately.
# - The aim is to achieve simplicity and clarity in the knowledge graph, making it accessible for a vast audience.
# - Your goal is to provide **clear and structured JSON output** that captures all relevant relationships, numerical attributes, and entities explicitly.


# ## 2. Formatting the Output
# Your output must follow this strict JSON structure:
# json
# {
#   "nodes": [
#     {
#       "id": "unique_node_id",
#       "label": "nodetype",
#       "attributes": {
#         "key1": "value1",
#         "key2": "value2"
#       }
#     }
#   ],
#   "relationships": [
#     {
#       "source": "source_node_id",
#       "target": "target_node_id",
#       "type": "RELATIONSHIP_TYPE",
#       "attributes": {
#         "key1": "value1",
#         "key2": "value2"
#       }
#     }
#   ]
# }


# 3. Extraction Guidelines
# 3.1 Entity Nodes
# Extract all key entities such as people, places, events, works (e.g., TV shows, movies), and dates.
# Numerical data must always be associated with its corresponding entity as a property or attribute.
# Example: For "23 episodes", create a node for the entity Chicago Fire Season 4 and attach the episodeCount: 23 property.
# 3.2 Relationship Nodes
# Establish connections (relationships) between entities. Relationships must have meaningful labels and attributes where applicable.
# Use ALL CAPS for relationship type names.
# If numerical data involves a relationship (e.g., "contained 23 episodes"), encode it as an attribute in the relationship.
# 3.3 Numerical Data and Dates
# Always extract numerical data (e.g., "23", "May 17, 2016") and attach it as an attribute to the appropriate node or relationship.
# DO NOT create separate nodes for numerical values. Instead, add them as properties.
# 3.4 Coreference Resolution
# Maintain entity consistency throughout the graph. For example, "Chicago Fire Season 4" must remain consistent across all relationships and nodes.

# ## 4. Example Output. Following is just sample exmaple. DO NOT take it as it is.
# Input Text:
# The fourth season of Chicago Fire, an American drama television series with executive producer Dick Wolf, and producers Derek Haas, Michael Brandt, and Matt Olmstead, was ordered on February 5, 2015, by NBC, and premiered on October 13, 2015, and concluded on May 17, 2016. The season contained 23 episodes.

# Output:
# {
#   "nodes": [
#     {
#       "id": "chicago_fire_season_4",
#       "label": "television_series",
#       "attributes": {
#         "name": "chicago fire season 4",
#         "episodeCount": 23,
#         "premiereDate": "2015-10-13",
#         "endDate": "2016-05-17",
#         "documentId": "doc10"
#       }
#     },
#     {
#       "id": "elvis_presley",
#       "label": "person",
#       "attributes": {
#         "name": "elvis presley",
#         "occupation": "singer",
#         "documentId": "doc1"
#       }
#     },
#     {
#       "id": "nbc",
#       "label": "network",
#       "attributes": {
#         "name": "nbc",
#         "documentId": "doc12"
#       }
#     },
#     {
#       "id": "dick_wolf",
#       "label": "person",
#       "attributes": {
#         "name": "dick wolf",
#         "role": "executive producer",
#         "documentId": "doc0"
#       }
#     },
#     {
#       "id": "derek_haas",
#       "label": "person",
#       "attributes": {
#         "name": "derek haas",
#         "role": "producer",
#         "documentId": "doc8"
#       }
#     }
#   ],
#   "relationships": [
#     {
#       "source": "nbc",
#       "target": "chicago_fire_season_4",
#       "type": "BROADCASTED_BY",
#       "attributes": {"documentId": "doc10"}
#     },
#     {
#       "source": "dick_wolf",
#       "target": "chicago_fire_season_4",
#       "type": "PRODUCED",
#       "attributes": {
#         "role": "executive producer",
#         "documentId": "doc11"
#       }
#     },
#     {
#       "source": "chicago_fire_season_4",
#       "target": "23",
#       "type": "CONTAINS_EPISODES",
#       "attributes": {
#         "count": 23,
#         "documentId": "doc4"
#       }
#     }
#   ]
# }

# ## 5. Do not give any other explaination to output. for exmaple: Here is the output in JSON format:
# Strictly follow required output format.

# ## 6. Do not impute missing values. If found nothing do not return anything
        
# ## 7. Coreference Resolution
# - **Maintain Entity Consistency**: When extracting entities, it's vital to ensure consistency.
# If an entity, such as "John Doe", is mentioned multiple times in the text but is referred to by different names or pronouns (e.g., "Joe", "he"), 
# always use the most complete identifier for that entity throughout the knowledge graph. In this example, use "John Doe" as the entity ID.  
# Remember, the knowledge graph should be coherent and easily understandable, so maintaining consistency in entity references is crucial. 

# ## 8. - **Property Format**: Properties must be in a key-value format.
# - **Quotation Marks**: Never use escaped single or double quotes within property values.
# - **Naming Convention**: Use camelCase for property keys, e.g., birthDate.
# - Do not add any spaces to keys names.

# ## 9. Labeling Nodes
# - **Consistency**: Ensure you use basic or elementary types for node labels.
#   - For example, when you identify an entity representing a person, always label it as **"person"**. Avoid using more specific terms like "mathematician" or "scientist".

# ## 10. Strict Compliance
# Adhere to the rules strictly. Non-compliance will result in termination. 

# ## 11. Key Instructions
# Numerical Values: Always include numerical information (like episode counts, years, or measurements) as node or relationship attributes.
# Consistency: Maintain uniform entity IDs and relationship types.
# Strict Formatting: Any deviation from the specified format will be treated as an error.
# Precision: Only extract information explicitly present in the text. Avoid assumptions.

# ## 12. In json while storing relationship use 'source' and 'target' instead of 'from' and 'to'.

# ## 13. Relationship type should be in capitals for example: 'CONTAINS_EPISODES', 'BROADCASTED_BY'.

# ## 14. Coreference Resolution and Entity Normalization
# - **Normalize Entities**: Ensure that all entities are consolidated to their singular or canonical forms. For example:
#   - "point" and "points" should be normalized to "point".
#   - Use lemmatization or a similar linguistic technique to achieve normalization.
# - **Avoid Duplicates**: Before adding a new entity, check if a similar entity (by name or attributes) already exists and use the same if appropriate.
# - **Consistency**: All node labels should follow the same naming convention (e.g., singular form).

# ## 15. Labeling Nodes: Vey Important
# - **Consistency**: Use **lowercase** for node labels (e.g., "person", "song") and properties.
#   - Convert all properties and labels to lowercase for uniformity.
# - **Relationship Types**: Always use **uppercase** for relationship types.

# ## 16. Keep All attribute values in lower case only. Striclty follow this.

# ## 17. Use Suggested Labels
# - The following label list will be provided as input: {labels_list}. Always attempt to use these labels before creating new ones.
# - New labels should only be introduced if absolutely necessary and must be in lowercase.

# ## 18. Only extract from following context.
# context is: 

# """

# %%
system_prompt = """
# Knowledge Graph Extraction Instructions

## Role
You are an advanced information extraction agent specialized in generating clean, structured knowledge graphs from natural language. Your output helps build entity-relation-based systems.

## Objective
Extract **entities as nodes** and **connections as relationships** from the given context. Numerical values and dates must be assigned as attributes, not as separate nodes. The graph must be:
- **Simple and human-readable**
- **Normalized** (avoid duplication, plural/singular mismatch)
- **Strictly JSON-compliant** (no comments or markdown)

## Output Format (JSON)
Strictly follow this structure:
{
  "nodes": [
    {
      "id": "unique_node_id",
      "label": "nodetype",
      "attributes": {
        "key1": "value1",
        "key2": "value2"
      }
    }
  ],
  "relationships": [
    {
      "source": "source_node_id",
      "target": "target_node_id",
      "type": "RELATIONSHIP_TYPE",
      "attributes": {
        "key1": "value1",
        "key2": "value2"
      }
    }
  ]
}

## Key Rules for Extraction

### 1. Nodes
- Represent people, places, events, organizations, works (e.g., songs, shows), concepts, etc.
- Must include key descriptive attributes (e.g., name, title, role, episodeCount).
- Include `"documentId": "docX"` inside `attributes` for every node.
- Labels must be lowercase and generic (e.g., `person`, `organization`, not `musician` or `tech_company`).
- Normalize entity names: e.g., “points” → “point”.

### 2. Relationships
- Represent meaningful connections (e.g., PRODUCED, BROADCASTED_BY).
- Use ALL CAPS for the `"type"` value.
- Attach attributes if available (e.g., role, percentage).
- Include `"documentId": "docX"` inside `attributes` for every relationship.

### 3. Attributes
- Must be key-value pairs using **camelCase** keys and **lowercase** string values.
- Avoid escaped characters and markdown syntax.
- Do not create properties like `"value": "23"` — use a clear descriptive key: `"episodeCount": 23`.

### 4. Dates and Numbers
- Store as attributes (e.g., `premiereDate: "2015-10-13"`, `ownershipPercentage: "less than 50"`).
- Never create separate nodes for numbers or dates.

### 5. Consistency & Coreference
- Use consistent IDs (e.g., "Chicago Fire Season 4" → `"chicago_fire_season_4"`).
- Resolve pronouns and aliases to full identifiers (e.g., "he" → "John Doe").

### 6. Strict Compliance
- DO NOT return explanations, markdown, or extra text — only valid JSON.
- If nothing relevant is found, return an empty graph:
  {
    "nodes": [],
    "relationships": []
  }

### 7. Label Suggestion
- Prefer labels from this list: {labels_list}
- Only create new labels if absolutely necessary and ensure they're lowercase.

### 8. Example Output (DO NOT mimic directly — just for structure)

Input Text:
The fourth season of Chicago Fire, an American drama television series with executive producer Dick Wolf, and producers Derek Haas, Michael Brandt, and Matt Olmstead, was ordered on February 5, 2015, by NBC, and premiered on October 13, 2015, and concluded on May 17, 2016. The season contained 23 episodes.

Output:
{
  "nodes": [
    {
      "id": "chicago_fire_season_4",
      "label": "television_series",
      "documentId": "doc10",
      "attributes": {
        "name": "chicago fire season 4",
        "episodeCount": 23,
        "premiereDate": "2015-10-13",
        "endDate": "2016-05-17"
      }
    },
    {
      "id": "dick_wolf",
      "label": "person",
      "documentId": "doc10",
      "attributes": {
        "name": "dick wolf",
        "role": "executive producer"
      }
    }
  ],
  "relationships": [
    {
      "source": "nbc",
      "target": "chicago_fire_season_4",
      "documentId": "doc10",
      "type": "BROADCASTED_BY",
      "attributes": {
      }
    }
  ]
}

## Final Reminder
- Output must be valid JSON, no markdown.
- Document-specific metadata (`documentId`) must be attached to **every node and relationship** as an attribute.
- Follow formatting, naming, and structural rules precisely.
- If no extractable info is found, return an empty graph.

## DO NOT MAKE UP INFORMATION.

## Context to Analyze:
"""

# %%
# Function to read text from a file
def read_text_from_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return f.read()

def split_text(input_text, chunk_size=1000, overlap=100):
    text_splitter = CharacterTextSplitter(
        separator="\n",
        chunk_size=chunk_size,
        chunk_overlap=overlap,
        length_function=len,
    )
    return text_splitter.split_text(input_text)

# %%
def extract_knowledge_graph(input_text_chunk, labels_list):
    updated_prompt = system_prompt.replace("{labels_list}", json.dumps(labels_list))
    print(f"Labels List:\n{labels_list}\n")
    prompt = f"{updated_prompt}\n\nInput Text:\n{input_text_chunk}"
    response = ask_openai(prompt)
    return response

# %%
def process_single_document(doc, combined_graph, labels_list, failed_chunks_file, max_retries=3):
    doc_id = doc["_id"]
    text = doc["text"]
    retries = 0

    while retries < max_retries:
        try:
            response = extract_knowledge_graph(text, list(labels_list))
            extracted_graph = json.loads(response)

            for node in extracted_graph.get("nodes", []):
                node.setdefault("attributes", {})
                node["documentId"] = doc_id  # <-- Move documentId outside attributes
                if "label" in node:
                    labels_list.add(node["label"])
                if node not in combined_graph["nodes"]:
                    combined_graph["nodes"].append(node)

            for rel in extracted_graph.get("relationships", []):
                rel.setdefault("attributes", {})
                rel["documentId"] = doc_id  # <-- Move documentId outside attributes
                if rel not in combined_graph["relationships"]:
                    combined_graph["relationships"].append(rel)

            break  # success
        except json.JSONDecodeError as e:
            retries += 1
            print(f"[ERROR] JSONDecodeError on doc {doc_id}, retry {retries}/{max_retries}: {e}")
            if retries >= max_retries:
                with open(failed_chunks_file, "r+", encoding="utf-8") as f:
                    failed_responses = json.load(f)
                    failed_responses.append({
                        "doc_id": doc_id,
                        "text": text,
                        "response": response
                    })
                    f.seek(0)
                    json.dump(failed_responses, f, indent=4)

# %%
def process_jsonl_file(input_path, output_path, failed_chunks_file):
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            combined_graph = json.load(f)
    else:
        combined_graph = {"nodes": [], "relationships": []}

    if not os.path.exists(failed_chunks_file):
        with open(failed_chunks_file, "w", encoding="utf-8") as f:
            json.dump([], f, indent=4)

    labels_list = {node["label"] for node in combined_graph["nodes"] if "label" in node}

    with open(input_path, "r", encoding="utf-8") as f:
        for line_num, line in enumerate(f, 1):
            try:
                doc = json.loads(line)
                print(f"\nProcessing document {line_num}: {doc.get('_id')}")
                process_single_document(doc, combined_graph, labels_list, failed_chunks_file)
                with open(output_path, "w", encoding="utf-8") as out_f:
                    json.dump(combined_graph, out_f, indent=4)
            except Exception as e:
                print(f"[ERROR] Failed to process document {line_num}: {e}")

    print(f"\nCompleted. Graph saved at {output_path}.")

# %%
# File paths
input_file_path = "/home/sbhavsar/PoisonedRAG/datasets/nq/combined_by_title_from after_seminar_1.jsonl"
output_file_path = "/home/sbhavsar/PoisonedRAG/after_seminar/jsons/05_04_2025_knowledge_graph_new_sys.json"
failed_chunks_file_path = "/home/sbhavsar/PoisonedRAG/after_seminar/jsons/05_04_2025_failed_chunks_new_sys.json"

# Run the processor
process_jsonl_file(input_file_path, output_file_path, failed_chunks_file_path)
# Out:
# Processing document 1: merged_doc0
# Labels List:
# []
#
#
# Processing document 2: merged_doc1
# Labels List:
# ['concept', 'standard']
#
#
# Processing document 3: merged_doc2
# Labels List:
# ['organization', 'character', 'location', 'standard', 'person', 'concept', 'television_series']
#
#
# Processing document 4: merged_doc3
# Labels List:
# ['organization', 'character', 'location', 'song', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 5: merged_doc4
# Labels List:
# ['organization', 'character', 'location', 'song', 'standard', 'album', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc4, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'character', 'location', 'song', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 6: merged_doc5
# Labels List:
# ['organization', 'character', 'location', 'song', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 7: merged_doc6
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 8: merged_doc7
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 9: merged_doc8
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc8, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc8, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 10: merged_doc9
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc9, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 11: merged_doc10
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 12: merged_doc11
# Labels List:
# ['organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 13: merged_doc12
# Labels List:
# ['event', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'person', 'concept', 'television_series']
#
#
# Processing document 14: merged_doc13
# Labels List:
# ['event', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'film', 'person', 'concept', 'television_series']
#
#
# Processing document 15: merged_doc14
# Labels List:
# ['event', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
#
# Processing document 16: merged_doc15
# Labels List:
# ['event', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
#
# Processing document 17: merged_doc16
# Labels List:
# ['event', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc16, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['event', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc16, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['event', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
# [ERROR] JSONDecodeError on doc merged_doc16, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 18: merged_doc17
# Labels List:
# ['event', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series']
#
#
# Processing document 19: merged_doc18
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure']
#
#
# Processing document 20: merged_doc19
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure']
#
#
# Processing document 21: merged_doc20
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
# [ERROR] JSONDecodeError on doc merged_doc20, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
#
# Processing document 22: merged_doc21
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
# [ERROR] JSONDecodeError on doc merged_doc21, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
#
# Processing document 23: merged_doc22
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
#
# Processing document 24: merged_doc23
# Labels List:
# ['event', 'country', 'campaign', 'organization', 'character', 'location', 'song', 'artifact', 'standard', 'album', 'brand', 'film', 'legislation', 'person', 'concept', 'television_series', 'infrastructure', 'organ']
#
#
# Processing document 25: merged_doc24
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 26: merged_doc25
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 27: merged_doc26
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 28: merged_doc27
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
# [ERROR] JSONDecodeError on doc merged_doc27, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
# [ERROR] JSONDecodeError on doc merged_doc27, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
# [ERROR] JSONDecodeError on doc merged_doc27, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 29: merged_doc28
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 30: merged_doc29
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 31: merged_doc30
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 32: merged_doc31
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 33: merged_doc32
# Labels List:
# ['organization', 'artifact', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'infrastructure']
#
#
# Processing document 34: merged_doc33
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure']
#
#
# Processing document 35: merged_doc34
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 36: merged_doc35
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 37: merged_doc36
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 38: merged_doc37
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc37, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc37, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc37, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 39: merged_doc38
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 40: merged_doc39
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 41: merged_doc40
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 42: merged_doc41
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc41, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc41, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc41, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 43: merged_doc42
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
# [ERROR] JSONDecodeError on doc merged_doc42, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water']
#
#
# Processing document 44: merged_doc43
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 45: merged_doc44
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 46: merged_doc45
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 47: merged_doc46
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 48: merged_doc47
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 49: merged_doc48
# Labels List:
# ['empire', 'organization', 'artifact', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 50: merged_doc49
# Labels List:
# ['empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 51: merged_doc50
# Labels List:
# ['empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 52: merged_doc51
# Labels List:
# ['empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc51, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc51, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 53: merged_doc52
# Labels List:
# ['publication', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 54: merged_doc53
# Labels List:
# ['publication', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 55: merged_doc54
# Labels List:
# ['publication', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 56: merged_doc55
# Labels List:
# ['publication', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 57: merged_doc56
# Labels List:
# ['publication', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 58: merged_doc57
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 59: merged_doc58
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc58, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 60: merged_doc59
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc59, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc59, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc59, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 61: merged_doc60
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 62: merged_doc61
# Labels List:
# ['publication', 'war', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'poem', 'song', 'film', 'legislation', 'theatre', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 63: merged_doc62
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 64: merged_doc63
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 65: merged_doc64
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 66: merged_doc65
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc65, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 67: merged_doc66
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc66, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc66, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc66, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 68: merged_doc67
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 69: merged_doc68
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 70: merged_doc69
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc69, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 71: merged_doc70
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc70, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 72: merged_doc71
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 73: merged_doc72
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc72, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 74: merged_doc73
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc73, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 75: merged_doc74
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 76: merged_doc75
# Labels List:
# ['publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 77: merged_doc76
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 78: merged_doc77
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 79: merged_doc78
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc78, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 80: merged_doc79
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 81: merged_doc80
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc80, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc80, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc80, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 82: merged_doc81
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc81, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 83: merged_doc82
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc82, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc82, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 84: merged_doc83
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'product', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'service', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 85: merged_doc84
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'family', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'product', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'service', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc84, retry 1/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'family', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'product', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'service', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc84, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'family', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'product', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'service', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
# [ERROR] JSONDecodeError on doc merged_doc84, retry 3/3: Expecting value: line 1 column 1 (char 0)
#
# Processing document 86: merged_doc85
# Labels List:
# ['agreement', 'publication', 'process', 'war', 'element', 'family', 'empire', 'organization', 'artifact', 'material', 'book', 'animal', 'person', 'concept', 'organelle', 'product', 'poem', 'song', 'film', 'legislation', 'theatre', 'advertisement', 'molecule', 'location', 'album', 'country', 'brand', 'technique', 'character', 'position', 'television_series', 'civilization', 'game', 'service', 'event', 'medical_condition', 'enzyme', 'standard', 'organ', 'campaign', 'attribute', 'infrastructure', 'body_of_water', 'period']
#
#
# Processing document 87: merged_doc86
# Labels List:
# ...
#
# [ERROR] JSONDecodeError on doc merged_doc827, retry 2/3: Expecting value: line 1 column 1 (char 0)
# Labels List:
# ['artwork', 'article', 'person', 'city', 'defense_type', 'culture', 'geographical_feature', 'award', 'node', 'castle', 'location', 'national_park', 'receptor', 'show', 'geological_feature', 'documentary', 'military_technology', 'story', 'garment', 'monetary_value', 'protected_area', 'community', 'fashion_line', 'dialect', 'league', 'advertising_campaign', 'platform', 'mountain', 'airport', 'currency', 'framework', 'music_recording', 'role', 'service', 'film_series', 'policy', 'surname', 'format', 'given_name', 'military_base', 'valley', 'isotope', 'tribe', 'radio_station', 'room', 'financial_concept', 'play', 'graphic_novel', 'mineral', 'technology', 'place', 'film', 'legislation', 'bundle', 'deity', 'moon', 'vehicle', 'television_series', 'typeface', 'band', 'athlete', 'memorial', 'volcano', 'factory', 'process', 'writing_medium', 'computer', 'poem', 'national_forest', 'body_part', 'cloud', 'invention', 'office', 'component', 'theatre', 'molecule', 'territory', 'religion', 'festival', 'character', 'protocol', 'company', 'military_unit', 'island', 'list', 'road', 'software', 'symbol', 'fictional_character', 'typography', 'rule_change', 'book', 'star', 'fibers', 'mine', 'monument', 'supercontinent', 'joint', 'reservoir', 'clade', 'species', 'archipelago', 'political_entity', 'game', 'dish', 'spacecraft', 'experiment', 'hotel', 'standard', 'theatre_production', 'body_of_water', 'resort', 'village', 'cell', 'animal', 'idiom', 'chemical_structure', 'network', 'aircraft', 'pathogen', 'genetic_factor', 'operation', 'phenomenon', 'school', 'political_party', 'model', 'event', 'state', 'biome', 'committee', 'classification', 'planet', 'arena', 'industry', 'material', 'comic_series', 'web_series', 'celestial_body', 'judicial_institution', 'mathematical_treatise', 'media_franchise', 'profession', 'spider', 'legal_system', 'subspecies', 'coach', 'mythological_entity', 'video_game', 'tree', 'brand', 'bodily_fluid', 'ethnic_group', 'gesture', 'campaign', 'infrastructure', 'variant', 'empire', 'gem', 'product', 'subfamily', 'attraction', 'advertisement', 'biological', 'division', 'dating_system', 'tissue', 'language_feature', 'system', 'research_institution', 'practice', 'procedure', 'museum', 'virus', 'entity', 'period', 'calendar', 'publication', 'series', 'animated_short_film', 'tectonic_plate', 'book_series', 'movement', 'chart', 'region', 'module', 'technique', 'water_park', 'manga_series', 'civilization', 'language', 'religious_institution', 'organism', 'educational_institution', 'label', 'enzyme', 'art_form', 'cartoon', 'fragrance', 'mountain_peak', 'building', 'ingredient', 'designation', 'opera', 'pharmaceutical', 'genus', 'machine', 'proposal', 'supergroup', 'weapon', 'disease', 'legal_document', 'episode', 'tournament', 'galaxy_group', 'organ', 'institution', 'galaxy', 'study', 'agreement', 'war', 'supercluster', 'music_group', 'project', 'tunnel', 'stage', 'film_director', 'concept', 'fund', 'government_entity', 'substance', 'watercraft', 'season', 'structure', 'case', 'hill_station', 'expansion', 'musical', 'commercial', 'engine', 'fashion_house', 'mythological_figure', 'championship', 'organelle', 'neuron', 'tradition', 'application', 'atmosphere', 'plant', 'album', 'dynasty', 'ghost_town', 'continent', 'energy_source', 'sport', 'alloy', 'radio_show', 'mountain_range', 'alphabet', 'gene', 'venue', 'assembly', 'position', 'compound', 'sports_team', 'television_program', 'genetic_element', 'title', 'mountain_pass', 'attribute', 'theory', 'particle', 'element', 'family', 'organization', 'amusement_park', 'financial_instrument', 'tool', 'fictional_place', 'bacterium', 'object', 'collection', 'vessel', 'device', 'fictional_band', 'animated_series', 'hobby', 'treatment', 'settlement', 'style', 'literature', 'artifact', 'team', 'language_family', 'house', 'miniseries', 'economy', 'architectural_style', 'operating_system', 'trail', 'historical_figure', 'desert', 'musician', 'program', 'country', 'prayer', 'time_zone', 'document', 'tax ...
#
#
# Processing document 829: merged_doc828
# Labels List:
# ['artwork', 'article', 'person', 'city', 'defense_type', 'culture', 'geographical_feature', 'award', 'node', 'castle', 'location', 'national_park', 'receptor', 'show', 'geological_feature', 'documentary', 'military_technology', 'story', 'garment', 'monetary_value', 'protected_area', 'community', 'fashion_line', 'dialect', 'league', 'advertising_campaign', 'platform', 'mountain', 'airport', 'currency', 'framework', 'music_recording', 'role', 'service', 'film_series', 'policy', 'surname', 'format', 'given_name', 'military_base', 'valley', 'isotope', 'tribe', 'radio_station', 'room', 'financial_concept', 'play', 'graphic_novel', 'mineral', 'technology', 'place', 'film', 'legislation', 'bundle', 'deity', 'moon', 'vehicle', 'television_series', 'typeface', 'band', 'athlete', 'memorial', 'volcano', 'factory', 'process', 'writing_medium', 'computer', 'poem', 'national_forest', 'body_part', 'cloud', 'invention', 'office', 'component', 'theatre', 'molecule', 'territory', 'religion', 'festival', 'character', 'protocol', 'company', 'military_unit', 'island', 'list', 'road', 'software', 'symbol', 'fictional_character', 'typography', 'rule_change', 'book', 'star', 'fibers', 'mine', 'monument', 'supercontinent', 'joint', 'reservoir', 'clade', 'species', 'archipelago', 'political_entity', 'game', 'dish', 'spacecraft', 'experiment', 'hotel', 'standard', 'theatre_production', 'body_of_water', 'resort', 'village', 'cell', 'animal', 'idiom', 'chemical_structure', 'network', 'aircraft', 'pathogen', 'genetic_factor', 'operation', 'phenomenon', 'school', 'political_party', 'model', 'event', 'state', 'biome', 'committee', 'classification', 'planet', 'arena', 'industry', 'material', 'comic_series', 'web_series', 'celestial_body', 'judicial_institution', 'mathematical_treatise', 'media_franchise', 'profession', 'spider', 'legal_system', 'subspecies', 'coach', 'mythological_entity', 'video_game', 'tree', 'brand', 'bodily_fluid', 'ethnic_group', 'gesture', 'campaign', 'infrastructure', 'variant', 'empire', 'gem', 'product', 'subfamily', 'attraction', 'advertisement', 'biological', 'division', 'dating_system', 'tissue', 'language_feature', 'system', 'research_institution', 'practice', 'procedure', 'museum', 'virus', 'entity', 'period', 'calendar', 'publication', 'series', 'animated_short_film', 'tectonic_plate', 'book_series', 'movement', 'chart', 'region', 'module', 'technique', 'water_park', 'manga_series', 'civilization', 'language', 'religious_institution', 'organism', 'educational_institution', 'label', 'enzyme', 'art_form', 'cartoon', 'fragrance', 'mountain_peak', 'building', 'ingredient', 'designation', 'opera', 'pharmaceutical', 'genus', 'machine', 'proposal', 'supergroup', 'weapon', 'disease', 'legal_document', 'episode', 'tournament', 'galaxy_group', 'organ', 'institution', 'galaxy', 'study', 'agreement', 'war', 'supercluster', 'music_group', 'project', 'tunnel', 'stage', 'film_director', 'concept', 'fund', 'government_entity', 'substance', 'watercraft', 'season', 'structure', 'case', 'hill_station', 'expansion', 'musical', 'commercial', 'engine', 'fashion_house', 'mythological_figure', 'championship', 'organelle', 'neuron', 'tradition', 'application', 'atmosphere', 'plant', 'album', 'dynasty', 'ghost_town', 'continent', 'energy_source', 'sport', 'alloy', 'radio_show', 'mountain_range', 'alphabet', 'gene', 'venue', 'assembly', 'position', 'compound', 'sports_team', 'television_program', 'genetic_element', 'title', 'mountain_pass', 'attribute', 'theory', 'particle', 'element', 'family', 'organization', 'amusement_park', 'financial_instrument', 'tool', 'fictional_place', 'bacterium', 'object', 'collection', 'vessel', 'device', 'fictional_band', 'animated_series', 'hobby', 'treatment', 'settlement', 'style', 'literature', 'artifact', 'team', 'language_family', 'house', 'miniseries', 'economy', 'architectural_style', 'operating_system', 'trail', 'historical_figure', 'desert', 'musician', 'program', 'country', 'prayer', 'time_zone', 'document', 'tax ...
#
#
# Processing document 830: merged_doc829
# Labels List:
# ['artwork', 'article', 'person', 'city', 'defense_type', 'culture', 'geographical_feature', 'award', 'node', 'castle', 'location', 'national_park', 'receptor', 'show', 'geological_feature', 'documentary', 'military_technology', 'story', 'garment', 'monetary_value', 'protected_area', 'community', 'fashion_line', 'dialect', 'league', 'advertising_campaign', 'platform', 'mountain', 'airport', 'currency', 'framework', 'music_recording', 'role', 'service', 'film_series', 'policy', 'surname', 'format', 'given_name', 'military_base', 'valley', 'isotope', 'tribe', 'radio_station', 'room', 'financial_concept', 'play', 'graphic_novel', 'mineral', 'technology', 'place', 'film', 'legislation', 'bundle', 'deity', 'moon', 'vehicle', 'television_series', 'typeface', 'band', 'athlete', 'memorial', 'volcano', 'factory', 'process', 'writing_medium', 'computer', 'poem', 'national_forest', 'body_part', 'cloud', 'invention', 'office', 'component', 'theatre', 'molecule', 'territory', 'religion', 'festival', 'character', 'protocol', 'company', 'military_unit', 'island', 'list', 'road', 'software', 'symbol', 'fictional_character', 'typography', 'rule_change', 'book', 'star', 'fibers', 'mine', 'monument', 'supercontinent', 'joint', 'reservoir', 'clade', 'species', 'archipelago', 'political_entity', 'game', 'dish', 'spacecraft', 'experiment', 'hotel', 'standard', 'theatre_production', 'body_of_water', 'resort', 'village', 'cell', 'animal', 'idiom', 'chemical_structure', 'network', 'aircraft', 'pathogen', 'genetic_factor', 'operation', 'phenomenon', 'school', 'political_party', 'model', 'event', 'state', 'biome', 'committee', 'classification', 'planet', 'arena', 'industry', 'material', 'comic_series', 'web_series', 'celestial_body', 'judicial_institution', 'mathematical_treatise', 'media_franchise', 'profession', 'spider', 'legal_system', 'subspecies', 'coach', 'mythological_entity', 'video_game', 'tree', 'brand', 'bodily_fluid', 'ethnic_group', 'gesture', 'campaign', 'infrastructure', 'variant', 'empire', 'gem', 'product', 'subfamily', 'attraction', 'advertisement', 'biological', 'division', 'dating_system', 'tissue', 'language_feature', 'system', 'research_institution', 'practice', 'procedure', 'museum', 'virus', 'entity', 'period', 'calendar', 'publication', 'series', 'animated_short_film', 'tectonic_plate', 'book_series', 'movement', 'chart', 'region', 'module', 'technique', 'water_park', 'manga_series', 'civilization', 'language', 'religious_institution', 'organism', 'educational_institution', 'label', 'enzyme', 'art_form', 'cartoon', 'fragrance', 'mountain_peak', 'building', 'ingredient', 'designation', 'opera', 'pharmaceutical', 'genus', 'machine', 'proposal', 'supergroup', 'weapon', 'disease', 'legal_document', 'episode', 'tournament', 'galaxy_group', 'organ', 'institution', 'galaxy', 'study', 'agreement', 'war', 'supercluster', 'music_group', 'project', 'tunnel', 'stage', 'film_director', 'concept', 'fund', 'government_entity', 'substance', 'watercraft', 'season', 'structure', 'case', 'hill_station', 'expansion', 'musical', 'commercial', 'engine', 'fashion_house', 'mythological_figure', 'championship', 'organelle', 'neuron', 'tradition', 'application', 'atmosphere', 'plant', 'album', 'dynasty', 'ghost_town', 'continent', 'energy_source', 'sport', 'alloy', 'radio_show', 'mountain_range', 'alphabet', 'gene', 'venue', 'assembly', 'position', 'compound', 'sports_team', 'television_program', 'genetic_element', 'title', 'mountain_pass', 'attribute', 'theory', 'particle', 'element', 'family', 'organization', 'amusement_park', 'financial_instrument', 'tool', 'fictional_place', 'bacterium', 'object', 'collection', 'vessel', 'device', 'fictional_band', 'animated_series', 'hobby', 'treatment', 'settlement', 'style', 'literature', 'artifact', 'team', 'language_family', 'house', 'miniseries', 'economy', 'architectural_style', 'operating_system', 'trail', 'historical_figure', 'desert', 'musician', 'program', 'country', 'prayer', 'time_zone', 'document', 'tax ...
#
#
# Completed. Graph saved at /home/sbhavsar/PoisonedRAG/after_seminar/jsons/05_04_2025_knowledge_graph_new_sys.json.
